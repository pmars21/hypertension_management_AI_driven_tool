# %%
# 1. Diccionario con las variables estáticas
nombres_variables = {
    # 1. Identificadores, Demografía y Pesos (DEMO_L)
    'SEQN': 'id_participante',
    'SDDSRVYR': 'ciclo_datos',
    'RIDSTATR': 'estado_entrevista',
    'RIDEXMON': 'periodo_examen',
    'RIAGENDR': 'genero',
    'RIDAGEYR': 'edad_anios',
    'RIDAGEMN': 'edad_meses',
    'RIDEXAGM': 'edad_meses_examen',
    'RIDRETH1': 'raza_etnia',
    'RIDRETH3': 'raza_etnia_ampliada',
    'DMDEDUC2': 'nivel_educacion',
    'DMDMARTZ': 'estado_civil',
    'DMQMILIZ': 'servicio_militar',
    'DMDBORN4': 'pais_nacimiento',
    'DMDYRUSR': 'tiempo_residencia_us',
    'DMDHHSIZ': 'tamano_hogar',
    'INDFMPIR': 'ratio_ingresos_pobreza',
    'DMDHRGND': 'genero_ref_hogar',
    'DMDHRAGZ': 'edad_ref_hogar',
    'DMDHREDZ': 'educacion_ref_hogar',
    'DMDHRMAZ': 'estado_civil_ref_hogar',
    'RIDEXPRG': 'estado_embarazo',
    'WTINT2YR': 'peso_entrevista_2a',
    'WTMEC2YR': 'peso_examen_mec_2a',
    'SDMVSTRA': 'estrato_varianza',
    'SDMVPSU': 'psu_varianza',

    # 2. Suplementos Dietéticos (DSQTOT_L)
    'WTDRD1': 'peso_dieta_dia1',
    'DSD010': 'toma_suplementos',
    'DSD010AN': 'toma_antiacidos',
    'DSDCOUNT': 'cant_suplementos',
    'DSDANCNT': 'cant_antiacidos',
    'DSQTKCAL': 'sup_energia_kcal',
    'DSQTPROT': 'sup_proteina',
    'DSQTCARB': 'sup_carbohidratos',
    'DSQTSUGR': 'sup_azucar',
    'DSQTFIBE': 'sup_fibra',
    'DSQTTFAT': 'sup_grasas_totales',
    'DSQTSFAT': 'sup_grasas_saturadas',
    'DSQTVC': 'sup_vitamina_c',
    'DSQTVD': 'sup_vitamina_d',
    'DSQTVB12': 'sup_vitamina_b12',
    'DSQTFA': 'sup_acido_folico',
    'DSQTCALC': 'sup_calcio',
    'DSQTIRON': 'sup_hierro',
    'DSQTMAGN': 'sup_magnesio',
    'DSQTZINC': 'sup_zinc',
    'DSQTCAFF': 'sup_cafeina',
    'DSQTLZ': 'sup_luteina',

    # 3. Prueba de Equilibrio / Balance (Variables generales)
    'BAXMSTAT': 'estado_examen_balance',
    'BAX5STAT': 'elegibilidad_balance_cond5',
    'BAXRXNC': 'razon_balance_parcial',
    'BAXRXND': 'razon_balance_no_realizado',

    # 4. Presión Arterial (BPXO_L)
    'BPAOARM': 'brazo_medicion_pa',
    'BPAOCSZ': 'tamano_manguito_pa',
    'BPXOSY1': 'pa_sistolica_1',
    'BPXOSY2': 'pa_sistolica_2',
    'BPXOSY3': 'pa_sistolica_3',
    'BPXODI1': 'pa_diastolica_1',
    'BPXODI2': 'pa_diastolica_2',
    'BPXODI3': 'pa_diastolica_3',
    'BPXOPLS1': 'pulso_1',
    'BPXOPLS2': 'pulso_2',
    'BPXOPLS3': 'pulso_3',

    # 5. Medidas Corporales (BMX_L)
    'BMDSTATS': 'estado_medidas_corp',
    'BMXWT': 'peso_kg',
    'BMIWT': 'nota_peso',
    'BMXHT': 'altura_cm',
    'BMIHT': 'nota_altura',
    'BMXRECUM': 'longitud_recostado_cm',
    'BMIRECUM': 'nota_longitud',
    'BMXHEAD': 'circunferencia_cabeza_cm',
    'BMIHEAD': 'nota_cabeza',
    'BMXBMI': 'imc',
    'BMDBMIC': 'categoria_imc_infantil',
    'BMXLEG': 'largo_pierna_superior_cm',
    'BMILEG': 'nota_pierna',
    'BMXARML': 'largo_brazo_superior_cm',
    'BMIARML': 'nota_largo_brazo',
    'BMXARMC': 'circunferencia_brazo_cm',
    'BMIARMC': 'nota_circunferencia_brazo',
    'BMXWAIST': 'circunferencia_cintura_cm',
    'BMIWAIST': 'nota_cintura',
    'BMXHIP': 'circunferencia_cadera_cm',
    'BMIHIP': 'nota_cadera',

    # 6. Elastografía Hepática / Hígado (LUX_L)
    'LUAXSTAT': 'estado_elastografia',
    'LUARXNC': 'razon_elasto_parcial',
    'LUARXND': 'razon_elasto_no_realizado',
    'LUARXIN': 'ineligibilidad_elasto',
    'LUAPNME': 'tipo_sonda_elasto',
    'LUANMTGP': 'intentos_totales_elasto',
    'LUANMVGP': 'medidas_validas_elasto',
    'LUXSMED': 'rigidez_mediana_kpa',
    'LUXSIQR': 'rigidez_iqr',
    'LUXSIQRM': 'ratio_iqr_mediana',
    'LUXCAPM': 'cap_mediana_db_m',
    'LUXCPIQR': 'cap_iqr',

    # 7. Analíticas de Orina y Sangre (Lab)
    'URXUMA': 'albumina_orina_ug_ml',
    'URXUMS': 'albumina_orina_mg_l',
    'URDUMALC': 'nota_albumina_orina',
    'URXUCR': 'creatinina_orina_mg_dl',
    'URXCRS': 'creatinina_orina_umol_l',
    'URDUCRLC': 'nota_creatinina_orina',
    'URDACT': 'ratio_albumina_creatinina',
    'WTPH2YR': 'peso_flebotomia_2a',
    'LBXWBCSI': 'leucocitos_totales',
    'LBXLYPCT': 'linfocitos_pct',
    'LBDLYMNO': 'linfocitos_abs',
    'LBXMOPCT': 'monocitos_pct',
    'LBDMONO': 'monocitos_abs',
    'LBXNEPCT': 'neutrofilos_pct',
    'LBDNENO': 'neutrofilos_abs',
    'LBXEOPCT': 'eosinofilos_pct',
    'LBDEONO': 'eosinofilos_abs',
    'LBXBAPCT': 'basofilos_pct',
    'LBDBANO': 'basofilos_abs',
    'LBXRBCSI': 'eritrocitos_totales',
    'LBXHGB': 'hemoglobina_g_dl',
    'LBXHCT': 'hematocrito_pct',
    'LBXMCVSI': 'volumen_corpuscular_medio',
    'LBXMC': 'conc_hemoglobina_media',
    'LBXMCHSI': 'hemoglobina_corpuscular_media',
    'LBXRDW': 'ancho_distribucion_eritrocitos',
    'LBXNRBC': 'eritrocitos_nucleados',
    'LBXPLTSI': 'plaquetas_totales',
    'LBXMPSI': 'volumen_plaquetario_medio',
    'LBDHDD': 'hdl_mg_dl',
    'LBDHDDSI': 'hdl_mmol_l',
    'LBXHSCRP': 'proteina_c_reactiva_mg_l',
    'LBDHRPLC': 'nota_proteina_c_reactiva',
    'LBXBPB': 'plomo_sangre_ug_dl',
    'LBDBPBSI': 'plomo_sangre_umol_l',
    'LBDBPBLC': 'nota_plomo',
    'LBXBCD': 'cadmio_sangre_ug_l',
    'LBDBCDSI': 'cadmio_sangre_nmol_l',
    'LBDBCDLC': 'nota_cadmio',
    'LBXTHG': 'mercurio_sangre_ug_l',
    'LBDTHGSI': 'mercurio_sangre_nmol_l',
    'LBDTHGLC': 'nota_mercurio',
    'LBXBSE': 'selenio_sangre_ug_l',
    'LBDBSESI': 'selenio_sangre_umol_l',
    'LBDBSELC': 'nota_selenio',
    'LBXBMN': 'manganeso_sangre_ug_l',
    'LBDBMNSI': 'manganeso_sangre_nmol_l',
    'LBDBMNLC': 'nota_manganeso',
    'WTSAF2YR': 'peso_muestra_ayuno_2a',
    'LBXTLG': 'trigliceridos_mg_dl',
    'LBDTRSI': 'trigliceridos_mmol_l',
    'LBDLDL': 'ldl_friedewald_mg_dl',
    'LBDLDLSI': 'ldl_friedewald_mmol_l',
    'LBDLDLM': 'ldl_martin_mg_dl',
    'LBDLDMSI': 'ldl_martin_mmol_l',
    'LBDLDLN': 'ldl_nih_mg_dl',
    'LBDLDNSI': 'ldl_nih_mmol_l'
}

# 2. Generación automática de variables iterativas (Filtros e intentos de la Prueba de Equilibrio)

# Preguntas filtro de balance (BAQ110 a BAQ173)
# Asumiendo un rango común de preguntas numeradas; añade o quita si el dataset tiene saltos numéricos exactos
for i in range(110, 174):
    nombres_variables[f'BAQ{i}'] = f'filtro_balance_{i}'

# Variables de la prueba de equilibrio para cada condición (1-5) e intento (1-2)
for condicion in range(1, 6):
    for intento in range(1, 3):
        sufijo = f"{condicion}{intento}"
        nombres_variables[f'BAXPF{sufijo}'] = f'aprueba_cond{condicion}_int{intento}'
        nombres_variables[f'BAXTC{sufijo}'] = f'tiempo_seg_cond{condicion}_int{intento}'
        nombres_variables[f'BAARFC{sufijo}'] = f'razon_paro_cond{condicion}_int{intento}'

# Ejemplo de uso con Pandas:
# import pandas as pd
# df = pd.read_csv('merged_all.csv')
# df.rename(columns=nombres_variables, inplace=True)
